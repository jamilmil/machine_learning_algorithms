# %% [markdown]
# ## Data treatment

# %% [markdown]
# ### Load the RMSD Data
# Loading the CASP.csv file into a dataframe and print the shape and type of the data.
# The attribute informations are:
# + RMSD
#
# The root mean square deviation RMSD between corresponding atoms of two protein chains is a commonly used measure of similarity between two protein structures. It is the measure of the average distance between the atoms of the Tertiary structure of proteins (Superimposed Structure). The smaller the RMSD is between two structures, the more similar are these two structures.
# + F1: Total surface area:
#
# The total surface area or the solvent accessible surface area (SASA) of proteins is defined as the surface characterized around a protein by a hypothetical centre of a solvent sphere with the Van Der Waals contact surface of the molecule. It gives the surface area accessible to a solvent.
# + F2: Non polar exposed area:
#
# The non polar exposed area describes a protein's region that is incapable of forming hydrogen bonds with water.
# + F3: Fractional area of exposed non polar residue
#
# + F4: Fractional area of exposed non polar part of residue
#
# + F5: Molecular mass weighted exposed area
#
# + F6: Average deviation from standard exposed area of residue
#
# + F7: Euclidian distance:
#
# The Euclidean distance between the x,y and z coordinates  gives the similarity and dissimilarity between two protein structures.
# + F8: Secondary structure Gap penalty:
#
# The penalty for inserting gaps into an alignment between two protein sequences is a major determinant of the alignment accuracy. For instance, two protein sequences may be relatively similar but differ at certain intervals as one protein may have a different subunit compared to the other. Representing these differing sub-sequences as gaps will allow to treat these cases as "good matches".
# + F9: Spacial Distribution constraints (N,K Values):
#
# The spatial distribution of variation within proteins is shaped by evolutionary constraint and provides insight into the functional importance of protein regions and the potential pathogenicity of protein alterations.

# %%
import pandas as pd
data=pd.read_csv("CASP.csv")
print("Original data:\n",data)
# Out:
# Original data:
#           RMSD        F1       F2       F3        F4            F5        F6  \
# 0      17.284  13558.30  4305.35  0.31754  162.1730  1.872791e+06  215.3590
# 1       6.021   6191.96  1623.16  0.26213   53.3894  8.034467e+05   87.2024
# 2       9.275   7725.98  1726.28  0.22343   67.2887  1.075648e+06   81.7913
# 3      15.851   8424.58  2368.25  0.28111   67.8325  1.210472e+06  109.4390
# 4       7.962   7460.84  1736.94  0.23280   52.4123  1.021020e+06   94.5234
# ...       ...       ...      ...      ...       ...           ...       ...
# 45725   3.762   8037.12  2777.68  0.34560   64.3390  1.105797e+06  112.7460
# 45726   6.521   7978.76  2508.57  0.31440   75.8654  1.116725e+06  102.2770
# 45727  10.356   7726.65  2489.58  0.32220   70.9903  1.076560e+06  103.6780
# 45728   9.791   8878.93  3055.78  0.34416   94.0314  1.242266e+06  115.1950
# 45729  18.827  12732.40  4444.36  0.34905  157.6300  1.788897e+06  229.4590
#
#             F7   F8       F9
# ...

# %% [markdown]
# ### Data set's Information
# Get the number of observations, missing values and NaN values.

# %%
print("Data set's informations:\n",data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45730 entries, 0 to 45729
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RMSD    45730 non-null  float64
#  1   F1      45730 non-null  float64
#  2   F2      45730 non-null  float64
#  3   F3      45730 non-null  float64
#  4   F4      45730 non-null  float64
#  5   F5      45730 non-null  float64
#  6   F6      45730 non-null  float64
#  7   F7      45730 non-null  float64
#  8   F8      45730 non-null  int64
#  9   F9      45730 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 3.5 MB
# Data set's informations:
#  None

# %% [markdown]
# ### Number of observations of each of the RMSD

# %%
print("Number of observations of each of the RMSD:\n",data["RMSD"].value_counts())
# Out:
# Number of observations of each of the RMSD:
#  0.000     272
# 1.787      24
# 2.006      24
# 1.900      21
# 2.055      20
#          ...
# 16.185      1
# 13.721      1
# 14.013      1
# 6.370       1
# 17.435      1
# Name: RMSD, Length: 15903, dtype: int64

# %% [markdown]
# ### Statistical Description of the data set
# View basic statistical details like mean, std etc. of the CASP.csv data.
# + mean:
#
# The mean is the arithmetic average of a set of given numbers. Therefore, the mean in math is often referred to as simply the "average."
# + std:
#
# The standard deviation of a random variable is a measure of hox dispersed the data is in relation to the mean. Low standard deviation means data are clustered around the mean and high standard deviation indicates datat are more spread out.
# + 25%:
#
# The 25th percentile, also known as the first, or lower quartile is the value at which 25% of the properties lie below that value, and 75% of the properties lie above that value.
# + 50%:
#
# 50th percentile, also known as the median, cuts the data set in half. Half of the properties lie below the median and half lie above the median.
# + 75%:
#
# 75th percentile, also known as the thire or upper quartile is the value at which 25% of the properties lie above that value and 75% of the answers lie below that value.
# + max and min:
#
# In mathematical analysis, the maxima and minima (the respective plurals of maximum and minimum) of a data set, known collectively as extrema (the plural of extremum), are the largest and smallest value of the data set.

# %%
print("Statistical description of the data set:\n",data.describe())
# Out:
# Statistical description of the data set:
#                 RMSD            F1            F2            F3            F4  \
# count  45730.000000  45730.000000  45730.000000  45730.000000  45730.000000
# mean       7.748528   9871.596995   3017.367175      0.302392    103.492433
# std        6.118312   4058.138034   1464.324663      0.062886     55.424985
# min        0.000000   2392.050000    403.500000      0.092500     10.310100
# 25%        2.305000   6936.680000   1979.045000      0.258740     63.563900
# 50%        5.030000   8898.805000   2668.155000      0.300150     87.740800
# 75%       13.379000  12126.150000   3786.410000      0.342890    133.646750
# max       20.999000  40034.900000  15312.000000      0.577690    369.317000
#
#                  F5            F6             F7            F8            F9
# count  4.573000e+04  45730.000000   45730.000000  45730.000000  45730.000000
# mean   1.368299e+06    145.638061    3989.755990     69.975071     34.523664
# ...

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Histogram

# %% [markdown]
# A histogram show how frequently a value falls into a particular bin. The height of each bar represents the number of values in the data set that fall within a particular bin.

# %%
import pandas as pd
import matplotlib.pyplot as plt
rmsd = pd.read_csv("CASP.csv")
rmsd.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# ### Correlation between variables of the CASP data

# %% [markdown]
# Heatmaps are used to show the relationships between the variables of a data set, one plotted on each axis. By observing how cell colors change across each axis, we can observe if there are any patterns in value for one or other variables.
#
# A correlation heatmap is a two dimensional plot of the amount of correlation between variables represented by colors. The varying intensity of the color represents the measure of the correlation.
#
# Correlation is a measure of linear relationship between two variables. When there are multiple variables, and we want to find the correlation between all of them, a matrix called correlation matrix is used.
#
# Seaborn package can plot heatmaps in python, and in order to determine the correlation, the pandas package is used.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
casp = pd.read_csv("CASP.csv")
X = casp.iloc[:, 1:]
f, ax = plt.subplots(figsize=(10, 8))
corr = X.corr()
print(corr)
sns.heatmap(corr, mask=np.zeros_like(corr), 
          cmap=sns.diverging_palette(200, 10, as_cmap=True),annot=True,square=True, ax=ax, linewidths=.5)
plt.show()
# Out:
#           F1        F2        F3        F4        F5        F6        F7  \
# F1  1.000000  0.906606  0.126285  0.931056  0.998185  0.967531  0.554002
# F2  0.906606  1.000000  0.502562  0.793143  0.902853  0.908354  0.515929
# F3  0.126285  0.502562  1.000000  0.031230  0.122622  0.200650  0.080064
# F4  0.931056  0.793143  0.031230  1.000000  0.925707  0.938108  0.485185
# F5  0.998185  0.902853  0.122622  0.925707  1.000000  0.961769  0.553729
# F6  0.967531  0.908354  0.200650  0.938108  0.961769  1.000000  0.538198
# F7  0.554002  0.515929  0.080064  0.485185  0.553729  0.538198  1.000000
# F8  0.651251  0.584242  0.095340  0.676919  0.642961  0.662584  0.347030
# F9 -0.898240 -0.786188 -0.069039 -0.891766 -0.897765 -0.881973 -0.521148
#
#           F8        F9
# F1  0.651251 -0.898240
# F2  0.584242 -0.786188
# F3  0.095340 -0.069039
# F4  0.676919 -0.891766
# F5  0.642961 -0.897765
# F6  0.662584 -0.881973
# F7  0.347030 -0.521148
# F8  1.000000 -0.637287
# ...

# %% [markdown]
# Each cell shows the correlation between the variables on each axis. Correlation ranges from -1 to +1. Values closer to zero closer to mean there us no linear trend between the two variables.
#
# The close to 1 the correlation is the more positively correlated ther are; that is as one increases so does the other and the closer to 1 the stronger this relationship is. This is observed for the relation between F1 and F5 which indicates that the SASA is highly related to the Molecular mass weighted exposed area of the protein.
#
# A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases.
#
# The diagonals are all 1 because those squares are correlating each variable to itself so it's a perfect correlation.
#
# For the rest, the larger the number and "reder" the color is the higher the correlation between the two variables. This observed for the relationship between F1 and F6 (0.97) which tells us that the SASA is highly related to Average deviation from standard exposed area of residue. This result was similarly observed in this publication: https://pubmed.ncbi.nlm.nih.gov/9426291/
#
# The plot is also symmetrical about the diagonal since the same two variables are bieng paired together in those squares.

# %% [markdown]
# ### Box plot

# %% [markdown]
# A box and whisker plot—also called a box plot—displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum.

# %%
import pandas as pd
import seaborn as sns 
casp = pd.read_csv("CASP.csv")
box_data = casp #variable representing the data array
box_target = casp.RMSD #variable representing the labels array
sns.boxplot(data = box_data,width=0.5,fliersize=5)
sns.set(rc={'figure.figsize':(10,10)})

# %% [markdown]
# ## K-Nearest Neighbors Algorithm

# %% [markdown]
# The k-nearesr neighbors (KNN) algorithm is a simple, easy to-implement supervised machine learning algorithm that can be used to solve both classification and regression problems.
#
# A supervised machine learning algorithm (as opposed to an unsupervised machine learning algorithm) is one that relies on labeled input data to learn a function that produces an appropriate output when given new unlabeled data.
#
# In this study where are dealing with a regression problem. A regression problem has a real number (a number with a decimal point) as its output.

# %% [markdown]
# ### Data set split

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
casp = pd.read_csv("CASP.csv")
X = casp.iloc[:, 1:].values
y = casp.iloc[:,0].values
#Split arrays or matrices into random train and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
print("\n70% train data:")
print(X_train)
print(y_train)
print("\n30% test data:")
print(X_test)
print(y_test)
# Out:
# [17.284  6.021  9.275 ... 10.356  9.791 18.827]
#
# 70% train data:
# [[6.19099e+03 1.48021e+03 2.39090e-01 ... 2.94525e+03 5.20000e+01
#   4.05211e+01]
#  [4.94387e+03 1.23161e+03 2.49110e-01 ... 2.10206e+03 4.30000e+01
#   4.30347e+01]
#  [4.87107e+03 1.58895e+03 3.26200e-01 ... 1.85899e+03 1.80000e+01
#   4.36524e+01]
#  ...
#  [8.95763e+03 2.37227e+03 2.64830e-01 ... 4.01812e+03 1.68000e+02
#   3.36453e+01]
#  [8.84155e+03 2.85002e+03 3.22340e-01 ... 3.93834e+03 2.70000e+01
#   3.58341e+01]
#  [5.78144e+03 1.71167e+03 2.96060e-01 ... 2.21718e+03 1.40000e+01
#   4.28427e+01]]
# [13.058  2.691  2.709 ...  1.242 16.627 13.25 ]
#
# 30% test data:
# [[8.92637e+03 2.52133e+03 2.82450e-01 ... 3.33571e+03 6.00000e+00
#   3.65108e+01]
#  [1.01699e+04 1.98534e+03 1.95210e-01 ... 3.99994e+03 5.90000e+01
#   3.33032e+01]
#  [6.63152e+03 1.56538e+03 2.36050e-01 ... 3.26446e+03 4.00000e+01
#   4.06895e+01]
#  ...
#  [1.25865e+04 3.19177e+03 2.53580e-01 ... 4.78668e+03 6.00000e+01
# ...

# %% [markdown]
# ### Training the model using the K nearest neighbor algorithm

# %%
# Import necessary modules 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.model_selection import train_test_split  
from sklearn import metrics
from sklearn import preprocessing
from sklearn import utils

casp = pd.read_csv("CASP.csv")
X = casp.iloc[:, 1:].values
y = casp.iloc[:,0].values
lab = preprocessing.LabelEncoder()
y= lab.fit_transform(y)
#Split arrays or matrices into train and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20) 
knn = KNeighborsClassifier(n_neighbors=7)  
knn.fit(X_train, y_train)   
a_index=list(range(1,11))
a=pd.Series(dtype="float")
# Calculate the accuracy of the model for different values of k
for i in np.arange(1, 10):
    knn2 = KNeighborsClassifier(n_neighbors=i)
    knn2.fit(X_train, y_train)
    print("For k = %d accuracy is"%i,knn2.score(X_test,y_test))
# Visual presentation: Various values of n for K-Nearest nerighbours
print("\nVisual presentation: Various values of n for K-Nearest nerighbours:")    
for i in list(range(1,11)):
    model=KNeighborsClassifier(n_neighbors=i) 
    model.fit(X_train,y_train)
    prediction=model.predict(X_test)
    a=a.append(pd.Series(metrics.accuracy_score(prediction,y_test)))
plt.plot(a_index, a)
# Out:
# For k = 1 accuracy is 0.1139295867045703
# For k = 2 accuracy is 0.07478679204023617
# For k = 3 accuracy is 0.05565274436912311
# For k = 4 accuracy is 0.0448283402580363
# For k = 5 accuracy is 0.038486770172753114
# For k = 6 accuracy is 0.03531598513011153
# For k = 7 accuracy is 0.03312923682484146
# For k = 8 accuracy is 0.031161163350098404
# For k = 9 accuracy is 0.028318390553247322
#
# Visual presentation: Various values of n for K-Nearest nerighbours:

# %% [markdown]
# ### Plot of K values vs accuracy

# %%
# Import necessary modules 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.model_selection import train_test_split  

casp = pd.read_csv("CASP.csv")
X = casp.iloc[:, 1:].values
y = casp.iloc[:,0].values
lab = preprocessing.LabelEncoder()
y= lab.fit_transform(y)
#Split arrays or matrices into train and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10) 
knn = KNeighborsClassifier(n_neighbors=7)  
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train,y_train)

print("Preliminary model score:")
print(knn.score(X_test,y_test))

no_neighbors = np.arange(1, 9)
train_accuracy = np.empty(len(no_neighbors))
test_accuracy = np.empty(len(no_neighbors))

for i, k in enumerate(no_neighbors):
    # We instantiate the classifier
    knn = KNeighborsClassifier(n_neighbors=k)
    # Fit the classifier to the training data
    knn.fit(X_train,y_train)
    
    # Compute accuracy on the training set
    train_accuracy[i] = knn.score(X_train, y_train)

    # Compute accuracy on the testing set
    test_accuracy[i] = knn.score(X_test, y_test)

# Visualization of k values vs accuracy

plt.title('k-NN: Varying Number of Neighbors')
plt.plot(no_neighbors, test_accuracy, label = 'Testing Accuracy')
plt.plot(no_neighbors, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Preliminary model score:
# 0.03695604635906407

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The results show that increasing K leads to a decrease in the variance of the model when we consider KNN as a regression model. When we do this, our predictor (or descriptor) becomes a function that determines continuous variables.
#
# In general, it is known that the KNN algorithm doesn't work well with a large dataset, since KNN is a distance based algorithm, the computational cost of calculating the distance between the new point and each existing point is very high which in turn degrades the performance of the algorithm.
#
# An alternative to this problem would be to go with the Linear Regression algorithms or the support vector machine (SVM).
